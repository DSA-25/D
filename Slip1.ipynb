# %% [raw]
# Q1.a.

# %%
from numpy import *
from sympy import *
from pulp import *
from pylab import *
from math import *
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
from pylab import *
import numpy as np
x=np.linspace(-1,1,100)
f=x**2
g=x**3
plot(x,f)
plot(x,g)
show()

# %% [raw]
# b.

# %%
x=np.linspace(-5,5,100)
y=np.exp(-x**2)
plot(x,y,"-.^g",label="$y=e^{-x^2}$")
xlabel('x')
ylabel('y')
title('graph of $Y=e^{-x^2}$')
legend()
show()

# %% [raw]
# c.

# %%
import matplotlib.pyplot as plt
left=[1,2,3,4,5]
height=[600,4000,2000,1500,700]
tick_label=["Clothing",'Food','Rent','Petrol','Misc']
plt.bar(left,height,tick_label=tick_label,width=0.5,color=['Green'])
plt.xlabel('sub')
plt.ylabel('% of passing')
plt.title('Marking scheme')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# Q.2.a

# %%
from sympy import *
x,y=symbols('x,y')
A=Point(5,3)
B=Point(1,4)
S=Segment(A,B)
S.reflect(Line(y-2*x+3))
# Out:
# Segment2D(Point2D(9/5, 23/5), Point2D(5, 2))

# %% [raw]
# b.

# %%
X=Point(0,0)
Y=Point(2,0)
Z=Point(2,3)
W=Point(1,6)
A=Polygon(X,Y,Z,W)
A.rotate(radians(180))
# Out:
# Polygon(Point2D(0, 0), Point2D(-2, 244929359829471/1000000000000000000000000000000), Point2D(-2, -3), Point2D(-1, -6))

# %% [raw]
# c.

# %%
a=Point(0,0)
b=Point(5,0)
c=Point(3,3)
T=Triangle(a,b,c)
T
# Out:
# Triangle(Point2D(0, 0), Point2D(5, 0), Point2D(3, 3))

# %%
T.area
# Out:
# 15/2

# %%
T.perimeter
# Out:
# sqrt(13) + 3*sqrt(2) + 5

# %% [raw]
# Q3.i.

# %%
from pulp import *

# %%
model=LpProblem(sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model+=(4*x+6*y<=24)
model+=(5*x+3*y<=15)
model+=150*x+75*y

# %%
model
# Out:
# NoName:
# MAXIMIZE
# 150*x + 75*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y <= 24
#
# _C2: 5 x + 3 y <= 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
model.solve()
# Out:
# 1

# %%
x.value()
# Out:
# 3.0

# %%
y.value()
# Out:
# 0.0

# %%
model.objective.value()
# Out:
# 450.0

# %% [raw]
# ii.

# %%
model=LpProblem(sense=LpMinimize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model+=(x>=6)
model+=(y>=6)
model+=(x+y<=11)
model+=x+y

# %%
model
# Out:
# NoName:
# MINIMIZE
# 1*x + 1*y + 0
# SUBJECT TO
# _C1: x >= 6
#
# _C2: y >= 6
#
# _C3: x + y <= 11
#
# VARIABLES
# x Continuous
# y Continuous

# %%
model.solve()
# Out:
# -1

# %%
x.value()
# Out:
# 6.0

# %%
y.value()
# Out:
# 6.0

# %%
model.objective.value()
# Out:
# 12.0

# %% [raw]
# b.i.

# %%
from sympy import *
from math import *

# %%
p=Point(3,-1)
p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,1]]))
# Out:
# Point2D(3, 1)

# %%
p.scale(2,1)
# Out:
# Point2D(6, -1)

# %%
p.scale(1,1.5)
# Out:
# Point2D(3, -3/2)

# %%
x,y=symbols("x,y")
p.reflect(Line(y-x))
# Out:
# Point2D(-1, 3)

# %% [raw]
# ii.

# %%
s1=Segment((5,-2),(4,3))

# %%
s1.rotate(radians(pi))
# Out:
# Segment2D(Point2D(51020930796169/10000000000000, -86148798699189/50000000000000), Point2D(382957760400909/100000000000000, 12858824440747/4000000000000))

# %%
s1.scale(2,1)
# Out:
# Segment2D(Point2D(10, -2), Point2D(8, 3))

# %%
A=Point(5,-2)
B=Point(4,3)
A1=A.transform(Matrix([[0,-1,0],[-1,0,0],[0,0,1]]))
B1=B.transform(Matrix([[0,-1,0],[-1,0,0],[0,0,1]]))
S=Segment(A1,B1)
S
# Out:
# Segment2D(Point2D(2, -5), Point2D(-3, -4))

# %%
A=Point(5,-2)
B=Point(4,3)
A1=A.transform(Matrix([[1,0,0],[4,1,0],[0,0,1]]))
B1=B.transform(Matrix([[1,0,0],[4,1,0],[0,0,1]]))
S=Segment(A1,B1)
S
# Out:
# Segment2D(Point2D(-3, -2), Point2D(16, 3))

# %%
x=np.linspace(0,2*pi)
f=cos(x)
plot(x,x)
show()

# %%
x=np.linspace(0,10,100)
f=log(10)*x
plot(x,f)
show()

# %%
left=[1,2,3,4,5]
hight=[65,30,54,10,20]
tick_label=['cricket','football','hokey','chess','tennis']
plt.bar(left,hight,tick_label=tick_label,width=0.7,color=['Green'])
plt.xlabel('sports')
plt.ylabel('nub of stu')
show()

# %%
x=np.linspace(0,5,100)
f=x**4
plot(x,f)
show()

# %%
model=LpProblem(sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model+=(4*x+6*y<=24)
model+=(5*x+3*y<=15)
model+=150*x+75*y

# %%
model
# Out:
# NoName:
# MAXIMIZE
# 150*x + 75*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y <= 24
#
# _C2: 5 x + 3 y <= 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
model.solve()
# Out:
# 1

# %%
x.value()
# Out:
# 3.0

# %%
y.value()
# Out:
# 0.0

# %%
model=LpProblem(sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model+=(x+y<=7)
model+=(2*x+5*y<=1)
model+=5*x+3*y

# %%
model
# Out:
# NoName:
# MAXIMIZE
# 5*x + 3*y + 0
# SUBJECT TO
# _C1: x + y <= 7
#
# _C2: 2 x + 5 y <= 1
#
# VARIABLES
# x Continuous
# y Continuous

# %%
model.solve()
# Out:
# 1

# %%
x.value()
# Out:
# 0.5

# %%
y.value()
# Out:
# 0.0

# %%
model.objective.value()
# Out:
# 2.5

# %%
 model=LpProblem(sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
z=LpVariable(name="z",lowBound=0)
w=LpVariable(name="w",lowBound=0)
model+=(4*x+6*y-5*z-4*w>=-20)
model+=(-3*x-2*y+4*z+w<=10)
model+=(-8*x-3*y+3*z+2*w<=20)
model+=4*x+y+3*z+5*w

# %%
model
# Out:
# NoName:
# MAXIMIZE
# 5*w + 4*x + 1*y + 3*z + 0
# SUBJECT TO
# _C1: - 4 w + 4 x + 6 y - 5 z >= -20
#
# _C2: w - 3 x - 2 y + 4 z <= 10
#
# _C3: 2 w - 8 x - 3 y + 3 z <= 20
#
# VARIABLES
# w Continuous
# x Continuous
# y Continuous
# z Continuous

# %%
model.solve()
# Out:
# -2

# %%
x.value()
# Out:
# 0.0

# %%
y.value()
# Out:
# 0.0

# %%
model.objective.value()
# Out:
# 25.0

# %%
x=np.linspace(-1,1,100)
f=sin(-1)*x
plot(x,f)
show()

# %%
model
# Out:
# NoName:
# MAXIMIZE
# 150*x + 75*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y <= 24
#
# _C2: 5 x + 3 y <= 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
model.solve()
# Out:
# 1

# %%
x.value()
# Out:
# 3.0

# %%
y.value()
# Out:
# 0.0

# %%
model.objective.value()
# Out:
# 450.0

# %%
p=Point(3,-1)
p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,-1]]))
# Out:
# Point2D(3, 1)

# %%
p.scale(2,1)
# Out:
# Point2D(6, -1)

# %%
p.scale(1,1.5)
# Out:
# Point2D(3, -3/2)

# %%
x,y=symbols("x,y")
p.reflect(Line(y-x))
# Out:
# Point2D(-1, 3)

# %% [markdown]
# model=LpProblem(sense=LpMaximize)
# x=LpVariable(name="x",lowBound=0)
# y=LpVariable(name="y",lowBound=0)
# model+=4*x+6*y<=24
# model+=5*x+3*y<=15
# model+=150*x+75*y

# %%
model=LpProblem(sense=LpMaximize)
x=LpVariable(name="x",lowBound=0)
y=LpVariable(name="y",lowBound=0)
model+=4*x+6*y<=24
model+=5*x+3*y<=15
model+=150*x+75*y

# %%
model
# Out:
# NoName:
# MAXIMIZE
# 150*x + 75*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y <= 24
#
# _C2: 5 x + 3 y <= 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
model.solve()
# Out:
# 1

# %%
x.value()
# Out:
# 3.0

# %%
y.value()
# Out:
# 0.0

# %%
model.objective.value()
# Out:
# 450.0

# %%
p=Point(4,-2)
p.transform(Matrix([[-1,0,0],[0,1,0],[0,0,1]]))
# Out:
# Point2D(-4, -2)

# %%
p.scale(3,1)
# Out:
# Point2D(12, -2)

# %%
p.scale(1,2.5)
# Out:
# Point2D(4, -5)

# %%
x,y=symbols("x,y")
p.reflect(Line(y+x))
# Out:
# Point2D(2, -4)

# %%
a=Point(4,-1)
b=Point(3,0)

# %%
l=Segment(a,b)

# %%
l.rotate(radians(pi))
# Out:
# Segment2D(Point2D(50609903307553/12500000000000, -389641244634353/500000000000000), Point2D(299549144959159/100000000000000, 164410995446369/1000000000000000))

# %%
l.scale(2,1)
# Out:
# Segment2D(Point2D(8, -1), Point2D(6, 0))

# %%
x,y=symbols("x,y")

# %%
l.reflect(Line(y-x))
# Out:
# Segment2D(Point2D(-1, 4), Point2D(0, 3))

# %%
a=Point(1,0)
b=Point(2,-1)

# %%
x,y=symbols("x,y")
l=Segment(a,b)
l
# Out:
# Segment2D(Point2D(1, 0), Point2D(2, -1))

# %%
l.rotate(pi)
# Out:
# Segment2D(Point2D(-1, 24492935982947/200000000000000000000000000000), Point2D(-2, 1))

# %%
a=Point(1,0)
b=Point(2,-1)
c=Point(5,0)

# %%
Point.is_collinear(a,b,c)
# Out:
# False

# %% [markdown]
# r1=Ray((1,0),(2,-1))

# %%
r1=Ray((1,0),(2,-1))

# %%
r1.length
# Out:
# oo

# %%
r1.slope
# Out:
# -1

# %%
x,y=symbols("x,y")
p=Point(3,6)
l.reflect(Line(x-2*y+4))
# Out:
# Segment2D(Point2D(-1, 4), Point2D(-6/5, 27/5))

# %%
#slip25

# %%
#Q.1
b
# Out:
# Point2D(2, -1)

# %%
x=np.linspace(-1,1)
f=np.sin(x)
plot(x,f)
show()

# %%
#Q2.
a
# Out:
# Point2D(1, 0)

# %%
a=Point(1,0)
b=Point(2,-1)

# %%
l=Segment(a,b)

# %%
l.rotate(pi)
# Out:
# Segment2D(Point2D(-1, 24492935982947/200000000000000000000000000000), Point2D(-2, 1))

# %%
#b

# %%
p=Point(5,2)
q=Point(5,-2)
r=Point(5,0)

# %%
Point.is_collinear(p,q,r)
# Out:
# True

# %%
r1=Ray((5,2),(5,-2))

# %%
r1.length
# Out:
# oo

# %%
r1.slope
# Out:
# oo

# %%
t=Triangle(p,q,r)

# %%
t
# Out:
# Segment2D(Point2D(5, -2), Point2D(5, 0))

# %%
p=Point(-2,4)

# %%
p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,1]]))
# Out:
# Point2D(-2, -4)

# %%
p.scale(6,1)
# Out:
# Point2D(-12, 4)

# %%
p.rotate(radians(30))
# Out:
# Point2D(-46650635094611/12500000000000, 9856406460551/4000000000000)

# %%
#sleep 24
a
# Out:
# Point2D(1, 0)

# %%
x=np.linspace(1,10)
f=np.log(3*x**2)
plt.plot(x,f,ls='--',color='Black')
show()

# %%
a=(3,5,5,3)
b=(3,6,2,3)

# %%
plt.plot(a,b)

# %%
a=Point(0,0) 
b=Point(1,0) 
c=Point(2,2) 
d=Point(1,4)

# %%
p=Polygon(a,b,c,d)

# %%
p
# Out:
# Polygon(Point2D(0, 0), Point2D(1, 0), Point2D(2, 2), Point2D(1, 4))

# %%
p.area
# Out:
# 4

# %%
p.perimeter
# Out:
# 1 + sqrt(17) + 2*sqrt(5)

# %%
#sleep 23

# %%
def f(x,y):
      return np.cos((x)+(y))
x=np.linspace(-1,1,100)
y=np.linspace(-1,1,100)
x,y=np.meshgrid(x,y)
z=f(x,y)
ax=plt.axes(projection='3d')
ax.plot_surface(x,y,z)
xlabel('x')
ylabel('y')
title('3D counter')
legend
show()

# %%
A=Point(1,1)
B=Point(2,-2)
C=Point(1,2)

# %%
t=Triangle(A,B,C)

# %%
t
# Out:
# Triangle(Point2D(1, 1), Point2D(2, -2), Point2D(1, 2))

# %%
t.rotate(radians(pi/2))
# Out:
# Triangle(Point2D(972212083267437/1000000000000000, 102703635045153/100000000000000), Point2D(41081454018061/20000000000000, -194442416653487/100000000000000), Point2D(944799949675393/1000000000000000, 202666056731101/100000000000000))

# %%
p=Point(-2,4)

# %%
p
# Out:
# Point2D(-2, 4)

# %%
p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,1]]))
# Out:
# Point2D(-2, -4)

# %%
x1=[0,2,2,1,0]
y1=[0,0,3,6,0]
plt.plot(x1,y1,'black')
plt.fill(x1,y1,'green')

# %%
from sympy import *
from math import *
p=Polygon((0,0),(2,0),(2,3),(1,6))
p.rotate(radians(pi))
# Out:
# Polygon(Point2D(0, 0), Point2D(199699429972773/100000000000000, 109607330297579/1000000000000000), Point2D(22907291303517/12500000000000, 310509877988917/100000000000000), Point2D(669675158971127/1000000000000000, 604578656433197/100000000000000))

# %%
from mpl_toolkits import mplot3d
from pylab
def f(x,y):
    return np.sin(x**2+y**2)
x=np.linspace(0,10,300)
x=np.linspace(0,10,300)
x,y=np.meshgrid(x,y)
z=f(x,y)
ax=plt.axes(projection='3d')
ax.plot_surface(x,y,z,camp='virdis')
xlabel('x')
ylabel('y')
title('3D counter')
legend
show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 6
#       4 x=np.linspace(0,10,300)
#       5 x,y=np.meshgrid(x,y)
# ----> 6 z=f(x,y)
#       7 ax=plt.axes(projection='3d')
#       8 ax.plot_surface(x,y,z,camp='virdis')
#
# Cell In[132], line 2, in f(x, y)
#       1 def f(x,y):
# ----> 2     return np.sin(x**2+y**2)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'LpVariable' and 'int'
